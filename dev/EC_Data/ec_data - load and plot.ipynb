# %% [markdown]
# # Test of EC Data
#
# ## 1. Import needed libraries

# %%
from pathlib import Path
from ec4py import EC_Data
from ec4py import Quantity_Value_Unit as QV
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from pathlib import Path
# ----> 2 from ec4py import EC_Data
#       3 from ec4py import Quantity_Value_Unit as QV
#
# File ~\Documents\GitHub\Python\EC4py\src\ec4py\__init__.py:12
#       1 # Leave it empty. This is just a special file that tells pip that your main module is in this folder.
#       2 # No need to add anything here. Feel free to delete this line when you make your own package.
#       3
#       4 #from anyt import EC_Data
#       5 """_summary_
#       6 Module for reading binary TDMS files produced by EC4 View\n
#       7
#       8 ec_data is used to load in the raw files.
#       9
#      10 """
# ---> 12 from .ec_data import EC_Data
#      13 from .ec_datas import EC_Datas
#      14 from .cv_data import CV_Data
#
# File ~\Documents\GitHub\Python\EC4py\src\ec4py\ec_data.py:5
#       1 """ Python module for reading TDMS files produced by LabView and specifically form EC4 DAQ.
#       2
#       3     This module contains the public facing API for reading TDMS files produced by EC4 DAQ.
#       4 """
# ----> 5 from nptdms import TdmsFile
#       6 import math
#       7 import numpy as np
#
# ModuleNotFoundError: No module named 'nptdms'

# %% [markdown]
# ## 2.Make a list of paths to the data files.

# %%
paths = []
path_to_dataSetFolder = Path(".").cwd().parent.parent / "test_data" /"CV"
print(path_to_dataSetFolder)
#paths.append( path_to_dataSetFolder / "CV_144913_ 3.tdms")
file = ( path_to_dataSetFolder / "CV_153559_ 3.tdms")
# Out:
# c:\Users\gustav.wiberg\Documents\GitHub\Python\EC4py\test_data\CV

# %% [markdown]
# ## 3. Load in the data files

# %%
data = EC_Data(file)

# %%
#plot = CVs.plot("" ,legend = "name", smooth_y=50)
data.plot("E","i",title = "i vs E")
data.plot("i","E",title = "E vs i")
# Out:
# (<matplotlib.lines.Line2D at 0x232f94423d0>,
#  <Axes: xlabel='i ( A)', ylabel='Voltage (V)'>)

# %% [markdown]
# ## 4. Levich analysis

# %%
slope1, slope2 = CVs.Levich(-0.5,"area_cm", y_smooth = 11, )
#use the argument to normalize the data
# Out:
# Levich analysis
# dir 	pos      	neg
#  :     	A cm^-2 / rpm^0.5 	A cm^-2 / rpm^0.5
# slope: 	-1.31e-04 	-1.37e-04

# %% [markdown]
# ## 5. Koutechy-Levich analysis

# %%
slope1, slope2 = CVs.KouLev(-0.5,"area", y_smooth = 5)
print(slope1 ** 1, slope1 ** -1)
#use the argument to normalize the data
# Out:
# KouLev analysis
# dir 	pos      	neg
#  : 	rpm^0.5 /A m^-2 	rpm^0.5 /A m^-2
# slope: 	-1.45e+00 	-1.14e+00
# -6.893e-01 A^-1 m^2 rpm^0.2 -1.451e+00 A m^-2 rpm^-0.2
